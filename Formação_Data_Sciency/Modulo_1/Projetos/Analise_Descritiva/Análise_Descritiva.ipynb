# %% [markdown]
# ***
# # <font color=green size=10>CURSO DE ESTATÍSTICA - PARTE 1</font>
# ***
#
# ## Trabalho de Análise Descritiva de um Conjunto de Dados
#
# Utilizando os conhecimentos adquiridos em nosso treinamento realize uma análise descritiva básica de um conjunto de dados retirados da Pesquisa Nacional por Amostra de Domicílios - 2015 do IBGE.
#
# Vamos construir histogramas, calcular e avaliar medidas de tendência central, medidas separatrizes e de dispersão dos dados.
#
# Siga o roteiro proposto e vá completando as células vazias. Procure pensar em mais informações interessantes que podem ser exploradas em nosso dataset.

# %% [markdown]
# # <font color=green>DATASET DO PROJETO</font>
# ***

# %% [markdown]
# ### Pesquisa Nacional por Amostra de Domicílios - 2015
#
# A <b>Pesquisa Nacional por Amostra de Domicílios - PNAD</b> investiga anualmente, de forma permanente, características gerais da população, de educação, trabalho, rendimento e habitação e outras, com periodicidade variável, de acordo com as necessidades de informação para o país, como as características sobre migração, fecundidade, nupcialidade, saúde, segurança alimentar, entre outros temas. O levantamento dessas estatísticas constitui, ao longo dos 49 anos de realização da pesquisa, um importante instrumento para formulação, validação e avaliação de políticas orientadas para o desenvolvimento socioeconômico e a melhoria das condições de vida no Brasil.

# %% [markdown]
# ### Fonte dos Dados
#
# https://ww2.ibge.gov.br/home/estatistica/populacao/trabalhoerendimento/pnad2015/microdados.shtm

# %% [markdown]
# ### Variáveis utilizadas
#
# > ### Renda
# > ***
#
# Rendimento mensal do trabalho principal para pessoas de 10 anos ou mais de idade.
#
# > ### Idade
# > ***
#
# Idade do morador na data de referência em anos.
#
# > ### Altura (elaboração própria)
# > ***
#
# Altura do morador em metros.
#
# > ### UF
# > ***
#
# |Código|Descrição|
# |---|---|
# |11|Rondônia|
# |12|Acre|
# |13|Amazonas|
# |14|Roraima|
# |15|Pará|
# |16|Amapá|
# |17|Tocantins|
# |21|Maranhão|
# |22|Piauí|
# |23|Ceará|
# |24|Rio Grande do Norte|
# |25|Paraíba|
# |26|Pernambuco|
# |27|Alagoas|
# |28|Sergipe|
# |29|Bahia|
# |31|Minas Gerais|
# |32|Espírito Santo|
# |33|Rio de Janeiro|
# |35|São Paulo|
# |41|Paraná|
# |42|Santa Catarina|
# |43|Rio Grande do Sul|
# |50|Mato Grosso do Sul|
# |51|Mato Grosso|
# |52|Goiás|
# |53|Distrito Federal|
#
# > ### Sexo
# > ***
#
# |Código|Descrição|
# |---|---|
# |0|Masculino|
# |1|Feminino|
#
# > ### Anos de Estudo
# > ***
#
# |Código|Descrição|
# |---|---|
# |1|Sem instrução e menos de 1 ano|
# |2|1 ano|
# |3|2 anos|
# |4|3 anos|
# |5|4 anos|
# |6|5 anos|
# |7|6 anos|
# |8|7 anos|
# |9|8 anos|
# |10|9 anos|
# |11|10 anos|
# |12|11 anos|
# |13|12 anos|
# |14|13 anos|
# |15|14 anos|
# |16|15 anos ou mais|
# |17|Não determinados|
# ||Não aplicável|
#
# > ### Cor
# > ***
#
# |Código|Descrição|
# |---|---|
# |0|Indígena|
# |2|Branca|
# |4|Preta|
# |6|Amarela|
# |8|Parda|
# |9|Sem declaração|

# %% [markdown]
# #### <font color='red'>Observação</font>
# ***
# > Os seguintes tratamentos foram realizados nos dados originais:
# > 1. Foram eliminados os registros onde a <b>Renda</b> era inválida (999 999 999 999);
# > 2. Foram eliminados os registros onde a <b>Renda</b> era missing;
# > 3. Foram considerados somente os registros das <b>Pessoas de Referência</b> de cada domicílio (responsável pelo domicílio).

# %% [markdown]
# ***
# ***

# %% [markdown]
# ### Utilize a célula abaixo para importar as biblioteca que precisar para executar as tarefas
# #### <font color='red'>Sugestões: pandas, numpy, seaborn</font>

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
import numpy as np
from scipy import stats

# %% [markdown]
# ### Importe o dataset e armazene o conteúdo em uma DataFrame

# %%
dados = pd.read_csv('dados.csv', sep=',')

# %% [markdown]
# ### Visualize o conteúdo do DataFrame

# %%
dados
# Out:
#        UF  Sexo  Idade  Cor  Anos de Estudo  Renda    Altura
# 0      11     0     23    8              12    800  1.603808
# 1      11     1     23    2              12   1150  1.739790
# 2      11     1     35    8              15    880  1.760444
# 3      11     0     46    2               6   3500  1.783158
# 4      11     1     47    8               9    150  1.690631
# ...    ..   ...    ...  ...             ...    ...       ...
# 76835  53     1     46    2              11    812  1.687030
# 76836  53     0     30    4               7   1500  1.792934
# 76837  53     0     32    8              12   1300  1.830587
# 76838  53     0     57    8               4   1500  1.726344
# 76839  53     0     38    8               4    900  1.658305
#
# [76840 rows x 7 columns]

# %% [markdown]
# ### Para avaliarmos o comportamento da variável RENDA vamos construir uma tabela de frequências considerando as seguintes classes em salários mínimos (SM)
# #### <font color='blue'>Descreva os pontos mais relevantes que você observa na tabela e no gráfico.</font>
#
# Classes de renda:
#
# <b>A</b> ► Acima de 25 SM
#
# <b>B</b> ► De 15 a 25 SM
#
# <b>C</b> ► De 5 a 15 SM
#
# <b>D</b> ► De 2 a 5 SM
#
# <b>E</b> ► Até 2 SM
#
# Para construir as classes de renda considere que o salário mínimo na época da pesquisa era de <b>R$ 788,00</b>.
#
# #### Siga os passos abaixo:

# %% [markdown]
# ### 1º Definir os intevalos das classes em reais (R$)

# %%
classes = [0,788*2,788*5,788*15,788*25,max(dados.Renda)]
classes
# Out:
# [0, 1576, 3940, 11820, 19700, 200000]

# %% [markdown]
# ### 2º Definir os labels das classes

# %%
labels = ['E','D','C','B','A']
labels
# Out:
# ['E', 'D', 'C', 'B', 'A']

# %% [markdown]
# ### 3º Construir a coluna de frequências

# %%
freq = pd.value_counts(
            pd.cut(
            x = dados.Renda,
            labels=labels,
            bins=classes,
            include_lowest=True,
            )
            )
pd.DataFrame(freq)
freq.index.names =['Classe']

# %% [markdown]
# ### 4º Construir a coluna de percentuais

# %%
perc = pd.value_counts(
            pd.cut(
            x = dados.Renda,
            labels=labels,
            bins=classes,
            include_lowest=True
            ),
            normalize=True
            ).round(4) * 100
pd.DataFrame(perc)
perc.index.names = ['Classe']

# %% [markdown]
# ### 5º Juntar as colunas de frequência e percentuais e ordenar as linhas de acordo com os labels das classes

# %%
tabela = pd.merge(freq,perc,how='left',on='Classe')
tabela.columns = ['Frequência','Percentual']
tabela.reset_index(inplace=True)
tabela.rename_axis('ID', axis=1, inplace=True)
tabela.sort_values(by = 'Frequência', ascending=False)
# Out:
# ID Classe  Frequência  Percentual
# 0       E       49755       64.75
# 1       D       18602       24.21
# 2       C        7241        9.42
# 3       B         822        1.07
# 4       A         420        0.55

# %% [markdown]
# ### Construa um gráfico de barras para visualizar as informações da tabela de frequências acima

# %%
plot = sns.barplot(x=tabela['Classe'],y=tabela['Frequência'], palette='Blues_r', )
for i in plot.patches:
    #print(i)
    plot.annotate(i.get_height(),
                  (i.get_x() + i.get_width() / 2, i.get_height()), #Aqui pegamos a posição em x pra altura para posicionar na altura da barra e também a largura dividido por 2 para centralizar o texto
                  ha='center', #Alinhamento horizontal
                  va='baseline', #Alinhamento Vertical
                  fontsize=10, #Tamanho da Fonte
                  color='black', #Cor da fonte
                  xytext=(0, 2), #Posicionamento do texto a partir da sua atual posição
                  textcoords='offset points') #indicação de como será alterada sua coordenada, poderial ser como 'offset pixels' por exemplo

# %%
# Outra forma de realizar
plot = sns.barplot(x=tabela['Classe'],y=tabela['Frequência'], palette='Blues_r', )
for i in plot.containers:
    plot.bar_label(i,)

# %% [markdown]
# > ### Conclusões
#
# Top

# %% [markdown]
# ### Crie um histograma para as variáveis QUANTITATIVAS de nosso dataset
# #### <font color='blue'>Descreva os pontos mais relevantes que você observa nos gráficos (assimetrias e seus tipos, possíveis causas para determinados comportamentos etc.)</font>

# %%
#sns.set(rc={'figure.figsize':(14,6)}) # muda formato padrao para todos os plots

# %%
plt.figure(figsize=(14,6)) # Direto pelo matplot lib
n = dados.Idade.shape[0]
k = int((1 + (10 /3) * np.log10(n)).round(0))
print(k)
plot = sns.histplot(dados.Idade,bins=k,stat='frequency', element='bars', kde=True, kde_kws={'cut':3,'bw_adjust':3},)
#plot.figure.set_size_inches(14,6) # Outro método matplot lib
for i in plot.patches:
    #print(i)
    plot.annotate(int(i.get_height()),
                  (i.get_x() + i.get_width() / 2, i.get_height()), #Aqui pegamos a posição em x pra altura para posicionar na altura da barra e também a largura dividido por 2 para centralizar o texto
                  ha='center', #Alinhamento horizontal
                  va='baseline', #Alinhamento Vertical
                  fontsize=10, #Tamanho da Fonte
                  color='black', #Cor da fonte
                  rotation=0, #Rotaciona o texto
                  xytext=(0, 5), #Posicionamento do texto a partir da sua atual posição
                  textcoords='offset points') #indicação de como será alterada sua coordenada, poderial ser como 'offset pixels' por exemplo
#The `stat` parameter for `Hist` must be one of 'count', 'density', 'percent', 'probability' or 'frequency';
#Bins define a faixa, sem nada é automático pelo seaborn
#`element` must be one of ['bars', 'step', 'poly']
#kde_kws é um tipo dict, e possui argumentos como 'cut': indicar quantidade de desvios e o 'bw_adjust': suavização da curva quando kde = True
#dados.Idade.describe()
# Out:
# 17

# %%
plt.figure(figsize=(14,6)) # Direto pelo matplot lib
sns.histplot(dados.Altura,bins=17, kde=True,stat='frequency', kde_kws={'cut':3,'bw_adjust':3})
# Out:
# <Axes: xlabel='Altura', ylabel='Frequency'>

# %%
plot = sns.displot(dados.query('Renda <= 20000')['Renda'], kind='hist',kde=True,kde_kws={'cut':3,'bw_adjust':2},bins=20)
# Verificar # sns.ecdfplot(dados.query('Renda <= 20000')['Renda'])
plot.figure.set_size_inches(14,6) # Outro método matplot lib
# `kind` must be one of ['hist', 'kde', 'ecdf']

# %% [markdown]
# > ### Conclusões
#
# Primeiro Gráfico (Idade) = Possui uma assimetria a direita uma vez que o tipo de pesquisa, pega dados para maiores de 18 anos, sendo a pesquisa relacionada ao chefe de família.
# Segundo Gráfico (Altura) = Possui simetria, tendo a média, mediana e moda quase iguais. #DADOS FAKE
# Terceiro Gráfico (Renda) = Possui uma assimetria a direita, tendo uma frequencia maior para rendas mais baixas e frequencias mais distribuidas para classes mais altas. E também não existe uma renda negativa.

# %% [markdown]
# ### Para a variável RENDA, construa um histograma somente com as informações das pessoas com rendimento até R$ 20.000,00

# %%
plot = sns.displot(dados.query('Renda <= 20000')['Renda'], kind='hist',kde=True,kde_kws={'cut':3,'bw_adjust':2},bins=20)

# %% [markdown]
# ### Construa uma tabela de frequências e uma com os percentuais do cruzando das variáveis SEXO e COR
# #### <font color='blue'>Avalie o resultado da tabela e escreva suas principais conclusões</font>
# #### <font color='red'>Utilize os dicionários abaixo para renomear as linha e colunas das tabelas de frequências e dos gráficos em nosso projeto</font>

# %%
sexo = {
    0: 'Masculino', 
    1: 'Feminino'
}
cor = {
    0: 'Indígena', 
    2: 'Branca', 
    4: 'Preta', 
    6: 'Amarela', 
    8: 'Parda', 
    9: 'Sem declaração'
}
anos_de_estudo = {
    1: 'Sem instrução e menos de 1 ano', 
    2: '1 ano', 
    3: '2 anos', 
    4: '3 anos', 
    5: '4 anos', 
    6: '5 anos', 
    7: '6 anos', 
    8: '7 anos', 
    9: '8 anos', 
    10: '9 anos', 
    11: '10 anos', 
    12: '11 anos', 
    13: '12 anos', 
    14: '13 anos', 
    15: '14 anos', 
    16: '15 anos ou mais', 
    17: 'Não determinados'
}
uf = {
    11: 'Rondônia', 
    12: 'Acre', 
    13: 'Amazonas', 
    14: 'Roraima', 
    15: 'Pará', 
    16: 'Amapá', 
    17: 'Tocantins', 
    21: 'Maranhão', 
    22: 'Piauí', 
    23: 'Ceará', 
    24: 'Rio Grande do Norte', 
    25: 'Paraíba', 
    26: 'Pernambuco', 
    27: 'Alagoas', 
    28: 'Sergipe', 
    29: 'Bahia', 
    31: 'Minas Gerais', 
    32: 'Espírito Santo', 
    33: 'Rio de Janeiro', 
    35: 'São Paulo', 
    41: 'Paraná', 
    42: 'Santa Catarina', 
    43: 'Rio Grande do Sul', 
    50: 'Mato Grosso do Sul', 
    51: 'Mato Grosso', 
    52: 'Goiás', 
    53: 'Distrito Federal'
}

# %%
cruzamento_P = pd.crosstab(dados.Sexo,dados.Cor,normalize=True).rename(index=sexo,columns=cor)
print('%s\n' %(cruzamento_P*100).round(2))
# Out:
# Cor        Indígena  Branca  Preta  Amarela  Parda
# Sexo
# Masculino      0.33   28.88   7.16     0.31  32.62
# Feminino       0.13   12.52   3.76     0.15  14.14

# %%
cruzamento_N = pd.crosstab(dados.Sexo,dados.Cor,normalize=False).rename(index=sexo,columns=cor)
print(cruzamento_N)
# Out:
# Cor        Indígena  Branca  Preta  Amarela  Parda
# Sexo
# Masculino       256   22194   5502      235  25063
# Feminino        101    9621   2889      117  10862

# %% [markdown]
# > ### Conclusões
#
# Assim conseguimos cruzar informações de colunas das tabelas e abrir as informações mais detalhadas em relação a coluna e indices que indicamos

# %% [markdown]
# ## Realize, para a variável RENDA, uma análise descritiva com as ferramentas que aprendemos em nosso treinamento

# %% [markdown]
# ### Obtenha a média aritimética

# %%
dados.Renda.mean()
# Out:
# 2000.3831988547631

# %% [markdown]
# ### Obtenha a mediana

# %%
dados.Renda.median()
# Out:
# 1200.0

# %% [markdown]
# ### Obtenha a moda

# %%
dados.Renda.mode()
# Neste caso é multimodal
# Out:
# 0    788
# Name: Renda, dtype: int64

# %% [markdown]
# ### Obtenha o desvio médio absoluto

# %%
#dados.Renda.mad()
(dados.Renda - dados.Renda.mean()).abs().mean()
# Out:
# 1526.4951371638058

# %% [markdown]
# ### Obtenha a variância

# %%
dados.Renda.var()
# Out:
# 11044906.006217021

# %% [markdown]
# ### Obtenha o desvio-padrão

# %%
dados.Renda.std()
# Out:
# 3323.3877303464037

# %% [markdown]
# ### Obtenha a média, mediana e valor máximo da variável RENDA segundo SEXO e COR
# #### <font color='blue'>Destaque os pontos mais importante que você observa nas tabulações</font>
# #### <font color='red'>O parâmento <i>aggfunc</i> da função <i>crosstab()</i> pode receber uma lista de funções. Exemplo: <i>aggfunc = {'mean', 'median', 'max'}</i></font>

# %%
agregado = pd.crosstab(dados.Cor,dados.Sexo,values=dados.Renda,aggfunc={('Média',np.mean),('Mediana','median'),('Máximo','max')},normalize=False).round(2).rename(index=cor,columns=sexo) # type:ignore
agregado
# Out:
#            Mediana             Máximo              Média
# Sexo     Masculino Feminino Masculino Feminino Masculino Feminino
# Cor
# Indígena     797.5    788.0     10000   120000   1081.71  2464.39
# Branca      1700.0   1200.0    200000   100000   2925.74  2109.87
# Preta       1200.0    800.0     50000    23000   1603.86  1134.60
# Amarela     2800.0   1500.0     50000    20000   4758.25  3027.34
# Parda       1200.0    800.0    100000    30000   1659.58  1176.76

# %% [markdown]
# > ### Conclusões
#
# Escreva suas conclusões aqui...

# %% [markdown]
# ### Obtenha as medidas de dispersão da variável RENDA segundo SEXO e COR
# #### <font color='blue'>Destaque os pontos mais importante que você observa nas tabulações</font>
# #### <font color='red'>O parâmento <i>aggfunc</i> da função <i>crosstab()</i> pode receber uma lista de funções. Exemplo: <i>aggfunc = {'mad', 'var', 'std'}</i></font>

# %%
agregado = pd.crosstab(dados.Cor,dados.Sexo,values=dados.Renda,aggfunc={('Desvio Médio Absoluto','mad'),('Variância',np.var),('Desvio Padrão',np.std)},normalize=False).round(2).rename(index=cor,columns=sexo) # type:ignore
agregado
# Out:
# C:\Users\arkxd\AppData\Local\Temp\ipykernel_18784\4041904145.py:1: FutureWarning: The 'mad' method is deprecated and will be removed in a future version. To compute the same result, you may do `(df - df.mean()).abs().mean()`.
#   agregado = pd.crosstab(dados.Cor,dados.Sexo,values=dados.Renda,aggfunc={('Desvio Médio Absoluto','mad'),('Variância',np.var),('Desvio Padrão',np.std)},normalize=False).round(2).rename(index=cor,columns=sexo) # type:ignore
# C:\Users\arkxd\AppData\Local\Temp\ipykernel_18784\4041904145.py:1: FutureWarning: The 'mad' method is deprecated and will be removed in a future version. To compute the same result, you may do `(df - df.mean()).abs().mean()`.
#   agregado = pd.crosstab(dados.Cor,dados.Sexo,values=dados.Renda,aggfunc={('Desvio Médio Absoluto','mad'),('Variância',np.var),('Desvio Padrão',np.std)},normalize=False).round(2).rename(index=cor,columns=sexo) # type:ignore
# C:\Users\arkxd\AppData\Local\Temp\ipykernel_18784\4041904145.py:1: FutureWarning: The 'mad' method is deprecated and will be removed in a future version. To compute the same result, you may do `(df - df.mean()).abs().mean()`.
#   agregado = pd.crosstab(dados.Cor,dados.Sexo,values=dados.Renda,aggfunc={('Desvio Médio Absoluto','mad'),('Variância',np.var),('Desvio Padrão',np.std)},normalize=False).round(2).rename(index=cor,columns=sexo) # type:ignore
# C:\Users\arkxd\AppData\Local\Temp\ipykernel_18784\4041904145.py:1: FutureWarning: The 'mad' method is deprecated and will be removed in a future version. To compute the same result, you may do `(df - df.mean()).abs().mean()`.
#   agregado = pd.crosstab(dados.Cor,dados.Sexo,values=dados.Renda,aggfunc={('Desvio Médio Absoluto','mad'),('Variância',np.var),('Desvio Padrão',np.std)},normalize=False).round(2).rename(index=cor,columns=sexo) # type:ignore
# C:\Users\arkxd\AppData\Local\Temp\ipykernel_18784\4041904145.py:1: FutureWarning: The 'mad' method is deprecated and will be removed in a future version. To compute the same result, you may do `(df - df.mean()).abs().mean()`.
#   agregado = pd.crosstab(dados.Cor,dados.Sexo,values=dados.Renda,aggfunc={('Desvio Médio Absoluto','mad'),('Variância',np.var),('Desvio Padrão',np.std)},normalize=False).round(2).rename(index=cor,columns=sexo) # type:ignore
# C:\Users\arkxd\AppData\Local\Temp\ipykernel_18784\4041904145.py:1: FutureWarning: The 'mad' method is deprecated and will be removed in a future version. To compute the same result, you may do `(df - df.mean()).abs().mean()`.
#   agregado = pd.crosstab(dados.Cor,dados.Sexo,values=dados.Renda,aggfunc={('Desvio Médio Absoluto','mad'),('Variância',np.var),('Desvio Padrão',np.std)},normalize=False).round(2).rename(index=cor,columns=sexo) # type:ignore
# C:\Users\arkxd\AppData\Local\Temp\ipykernel_18784\4041904145.py:1: FutureWarning: The 'mad' method is deprecated and will be removed in a future version. To compute the same result, you may do `(df - df.mean()).abs().mean()`.
#   agregado = pd.crosstab(dados.Cor,dados.Sexo,values=dados.Renda,aggfunc={('Desvio Médio Absoluto','mad'),('Variância',np.var),('Desvio Padrão',np.std)},normalize=False).round(2).rename(index=cor,columns=sexo) # type:ignore
# C:\Users\arkxd\AppData\Local\Temp\ipykernel_18784\4041904145.py:1: FutureWarning: The 'mad' method is deprecated and will be removed in a future version. To compute the same result, you may do `(df - df.mean()).abs().mean()`.
#   agregado = pd.crosstab(dados.Cor,dados.Sexo,values=dados.Renda,aggfunc={('Desvio Médio Absoluto','mad'),('Variância',np.var),('Desvio Padrão',np.std)},normalize=False).round(2).rename(index=cor,columns=sexo) # type:ignore
# C:\Users\arkxd\AppData\Local\Temp\ipykernel_18784\4041904145.py:1: FutureWarning: The 'mad' method is deprecated and will be removed in a future version. To compute the same result, you may do `(df - df.mean()).abs().mean()`.
#   agregado = pd.crosstab(dados.Cor,dados.Sexo,values=dados.Renda,aggfunc={('Desvio Médio Absoluto','mad'),('Variância',np.var),('Desvio Padrão',np.std)},normalize=False).round(2).rename(index=cor,columns=sexo) # type:ignore
# C:\Users\arkxd\AppData\Local\Temp\ipykernel_18784\4041904145.py:1: FutureWarning: The 'mad' method is deprecated and will be removed in a future version. To compute the same result, you may do `(df - df.mean()).abs().mean()`.
#   agregado = pd.crosstab(dados.Cor,dados.Sexo,values=dados.Renda,aggfunc={('Desvio Médio Absoluto','mad'),('Variância',np.var),('Desvio Padrão',np.std)},normalize=False).round(2).rename(index=cor,columns=sexo) # type:ignore
#          Desvio Médio Absoluto          Desvio Padrão              Variância  \
# Sexo                 Masculino Feminino     Masculino  Feminino    Masculino
# Cor
# Indígena                798.91  3007.89       1204.09  11957.50   1449841.13
# Branca                 2261.01  1670.97       4750.79   3251.01  22570023.41
# Preta                   975.60   705.45       1936.31   1349.80   3749293.59
# Amarela                3709.60  2549.15       5740.82   3731.17  32957069.62
# Parda                  1125.83   811.58       2312.09   1596.23   5345747.15
#
#
# Sexo          Feminino
# Cor
# Indígena  1.429818e+08
# Branca    1.056909e+07
# Preta     1.821960e+06
# Amarela   1.392166e+07
# Parda     2.547960e+06

# %% [markdown]
# > ### Conclusões
#
# Escreva suas conclusões aqui...

# %% [markdown]
# ### Construa um box plot da variável RENDA segundo SEXO e COR
# #### <font color='blue'>É possível verificar algum comportamento diferenciado no rendimento entre os grupos de pessoas analisados? Avalie o gráfico e destaque os pontos mais importantes.</font>
# #### <font color='red'>1º - Utilize somente as informações de pessoas com renda abaixo de R$ 10.000</font>
# #### <font color='red'>2º - Para incluir uma terceira variável na construção de um boxplot utilize o parâmetro <i>hue</i> e indique a variável que quer incluir na subdivisão.</font>
# #### Mais informações: https://seaborn.pydata.org/generated/seaborn.boxplot.html

# %%
dados_plot = dados
dados_plot['Sexo'] = dados_plot['Sexo'].map(sexo,na_action=None) # na_action pod ser None ou Ignore
dados_plot['Cor'] = dados_plot['Cor'].map(cor,na_action=None)
dados_plot['UF'] = dados_plot['UF'].map(uf,na_action=None)
sns.boxplot(data = dados_plot.query('Renda < 10000'), x = 'Renda', y = 'Cor', hue = 'Sexo', orient = 'h')
# Out:
# <Axes: xlabel='Renda', ylabel='Cor'>

# %%
dados
# Out:
#                      UF       Sexo  Idade     Cor  Anos de Estudo  Renda  \
# 0              Rondônia  Masculino     23   Parda              12    800
# 1              Rondônia   Feminino     23  Branca              12   1150
# 2              Rondônia   Feminino     35   Parda              15    880
# 3              Rondônia  Masculino     46  Branca               6   3500
# 4              Rondônia   Feminino     47   Parda               9    150
# ...                 ...        ...    ...     ...             ...    ...
# 76835  Distrito Federal   Feminino     46  Branca              11    812
# 76836  Distrito Federal  Masculino     30   Preta               7   1500
# 76837  Distrito Federal  Masculino     32   Parda              12   1300
# 76838  Distrito Federal  Masculino     57   Parda               4   1500
# 76839  Distrito Federal  Masculino     38   Parda               4    900
#
#          Altura
# 0      1.603808
# 1      1.739790
# 2      1.760444
# 3      1.783158
# 4      1.690631
# ...         ...
# 76835  1.687030
# 76836  1.792934
# 76837  1.830587
# 76838  1.726344
# 76839  1.658305
#
# [76840 rows x 7 columns]

# %% [markdown]
# > ### Conclusões
#
# Escreva suas conclusões aqui...

# %% [markdown]
# # <font color="red">DESAFIO<font>
# ### Qual percentual de pessoas de nosso <i>dataset</i> ganham um salário mínimo (R$ 788,00) ou menos?
# #### <font color='red'>Utilize a função <i>percentileofscore()</i> do <i>scipy</i> para realizar estas análises.</font>
# #### Mais informações: https://docs.scipy.org/doc/scipy/reference/generated/scipy.stats.percentileofscore.html

# %%
from scipy import stats
stats.percentileofscore(dados.Renda, 788, kind='weak', nan_policy='propagate')
# Out:
# 28.867777199375325

# %% [markdown]
# ### Qual o valor máximo ganho por 99% das pessoas de nosso <i>dataset</i>?
# #### <font color='red'>Utilize o método <i>quantile()</i> do <i>pandas</i> para realizar estas análises.</font>

# %%
print(dados.Renda.quantile(0.99))
print(dados.Renda.median())
# Out:
# 15000.0
# 1200.0

# %% [markdown]
# ### Obtenha a média, mediana, valor máximo e desvio-padrão da variável RENDA segundo ANOS DE ESTUDO e SEXO
# #### <font color='blue'>Destaque os pontos mais importante que você observa nas tabulações</font>
# #### <font color='red'>O parâmento <i>aggfunc</i> da função <i>crosstab()</i> pode receber uma lista de funções. Exemplo: <i>aggfunc = ['mean', 'median', 'max', 'std']</i></font>

# %%
pd.crosstab(dados['Anos de Estudo'],dados.Sexo,values = dados['Renda'],aggfunc={('Média','mean'),('Mediana','median'),('Máximo','max')}).rename(index = anos_de_estudo)
# Out:
#                                 Mediana             Máximo            \
# Sexo                           Feminino Masculino Feminino Masculino
# Anos de Estudo
# Sem instrução e menos de 1 ano    390.0     700.0    10000     30000
# 1 ano                             400.0     788.0     2000     30000
# 2 anos                            450.0     788.0     4000     40000
# 3 anos                            500.0     800.0     3500     80000
# 4 anos                            788.0    1000.0    10000     50000
# 5 anos                            788.0    1045.0     8000     35000
# 6 anos                            788.0    1200.0     6000     25000
# 7 anos                            788.0    1200.0     9000     40000
# 8 anos                            800.0    1300.0    18000     30000
# 9 anos                            788.0    1200.0    20000     60000
# 10 anos                           800.0    1218.0     6000     45000
# 11 anos                          1000.0    1500.0   100000    200000
# 12 anos                          1200.0    1800.0   120000     30000
# 13 anos                          1300.0    2400.0    20000     25000
# 14 anos                          1600.0    2500.0    20000     50000
# 15 anos ou mais                  2800.0    4000.0   100000    200000
# Não determinados                  788.0    1200.0     3000      7000
#
#                                       Média
# Sexo                               Feminino    Masculino
# Anos de Estudo
# Sem instrução e menos de 1 ano   516.201748   799.494638
# 1 ano                            492.771987   895.629047
# 2 anos                           529.911638   931.178986
# 3 anos                           546.853916  1109.203862
# 4 anos                           704.279111  1302.329283
# 5 anos                           781.389776  1338.653218
# 6 anos                           833.732824  1448.875419
# 7 anos                           830.751004  1465.497940
# 8 anos                           933.615351  1639.396667
# 9 anos                           868.021700  1508.038850
# 10 anos                          925.919225  1731.270847
# 11 anos                         1286.790889  2117.060504
# 12 anos                         1682.313725  2470.330776
# 13 anos                         1911.730047  3195.099154
# 14 anos                         2226.460457  3706.620269
# 15 anos ou mais                 3899.513231  6134.279790
# Não determinados                 798.174419  1295.761905

# %% [markdown]
# ### Construa um box plot da variável RENDA segundo ANOS DE ESTUDO e SEXO
# #### <font color='blue'>É possível verificar algum comportamento diferenciado no rendimento entre os grupos de pessoas analisados? Avalie o gráfico e destaque os pontos mais importantes.</font>
# #### <font color='red'>1º - Utilize somente as informações de pessoas com renda abaixo de R$ 10.000</font>
# #### <font color='red'>2º - Utilize a variável IDADE para identificar se a desigualdade se verifica para pessoas de mesma idade. Exemplo: <i>data=dados.query('Renda < 10000 and Idade == 40')</i> ou <i>data=dados.query('Renda < 10000 and Idade == 50')</i></font>
# #### <font color='red'>3º - Para incluir uma terceira variável na construção de um boxplot utilize o parâmetro <i>hue</i> e indique a variável que quer incluir na subdivisão.</font>
# #### Mais informações: https://seaborn.pydata.org/generated/seaborn.boxplot.html

# %%
plt.figure(figsize=(16,10))
sns.boxplot(data = dados_plot.query('Renda < 10000 and Idade == 40'), x = 'Renda', y = 'Anos de Estudo', hue = 'Sexo', orient = 'h')

# %% [markdown]
# > ### Conclusões
#
# Escreva suas conclusões aqui...

# %% [markdown]
# ### Obtenha a média, mediana, valor máximo e desvio-padrão da variável RENDA segundo as UNIDADES DA FEDERAÇÃO
# #### <font color='blue'>Destaque os pontos mais importante que você observa nas tabulações</font>
# #### <font color='red'>Utilize o método <i>groupby()</i> do <i>pandas</i> juntamente com o método <i>agg()</i> para contruir a tabulação. O método <i>agg()</i> pode receber um dicionário especificando qual coluna do DataFrame deve ser utilizada e qual lista de funções estatísticas queremos obter, por exemplo: <i>dados.groupby(['UF']).agg({'Renda': ['mean', 'median', 'max', 'std']})</i></font>

# %%
#dados.groupby('UF').describe().Renda
dados.groupby('UF').agg({'Renda':[('Média','mean'),('Mediana','median'),('Máximo','max'),('Desvio Padrão','std')]}).round(2)
# Out:
#                        Renda
#                        Média Mediana  Máximo Desvio Padrão
# UF
# Acre                 1506.09   900.0   30000       2276.23
# Alagoas              1144.55   788.0   11000       1237.86
# Amapá                1861.35  1200.0   15580       2020.69
# Amazonas             1445.13   900.0   22000       1757.94
# Bahia                1429.65   800.0  200000       3507.92
# Ceará                1255.40   789.0   25000       1821.96
# Distrito Federal     4241.95  2000.0  100000       5550.46
# Espírito Santo       2026.38  1274.0  100000       3513.85
# Goiás                1994.58  1500.0   30000       2221.93
# Maranhão             1019.43   700.0   30000       1887.82
# Mato Grosso          2130.65  1500.0   35000       2542.63
# Mato Grosso do Sul   2262.60  1500.0   42000       3031.42
# Minas Gerais         2056.43  1200.0  100000       3584.72
# Paraná               2493.87  1500.0  200000       4302.94
# Paraíba              1293.37   788.0   30000       1950.27
# Pará                 1399.08   850.0   50000       2053.78
# Pernambuco           1527.08   900.0   50000       2389.62
# Piauí                1074.55   750.0   40000       2373.36
# Rio Grande do Norte  1344.72   800.0   15500       1651.81
# Rio Grande do Sul    2315.16  1500.0   35000       2913.34
# Rio de Janeiro       2496.40  1400.0  200000       5214.58
# Rondônia             1789.76  1200.0   50000       2406.16
# Roraima              1783.59  1000.0   20000       2079.66
# Santa Catarina       2470.85  1800.0   80000       3137.65
# Sergipe              1109.11   788.0   16000       1479.00
# São Paulo            2638.10  1600.0   80000       3503.78
# Tocantins            1771.09  1000.0   60000       2934.59

# %% [markdown]
# ### Construa um box plot da variável RENDA segundo as UNIDADES DA FEDERAÇÃO
# #### <font color='blue'>É possível verificar algum comportamento diferenciado no rendimento entre os grupos analisados? Avalie o gráfico e destaque os pontos mais importantes.</font>
# #### <font color='red'>1º - Utilize somente as informações de pessoas com renda abaixo de R$ 10.000</font>

# %%
plt.figure(figsize=(16,8))
sns.boxplot(data=dados.query('Renda < 10000').sort_values('Renda', ascending=False),x = 'Renda', y = 'UF',palette='Blues_r')
plt.ylabel('Estados')
# Out:
# Text(0, 0.5, 'Estados')

# %% [markdown]
# > ### Conclusões
#
# Escreva suas conclusões aqui...
